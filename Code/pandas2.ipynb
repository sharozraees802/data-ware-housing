# %%
import pandas as pd

# %%
emp = pd.read_csv("F:/DataSets/emp.csv")

# %%
emp.columns
# Out:
# Index(['empno', 'ename', 'job', 'mgr', 'hiredate', 'sal', 'comm', 'deptno'], dtype='object')

# %%
emp.shape
# Out:
# (14, 8)

# %%
print("Row: ", emp.shape[0])
print("Columns: ", emp.shape[1])
# Out:
# Row:  14
# Columns:  8

# %%
len(emp)
# Out:
# 14

# %%
emp
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno
# 0    7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2    7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 3    7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0  02/20/2001  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0  09/08/2001  1500     0.0      30
# 7    7900   JAMES      CLERK  7698.0  12/03/2001   950     NaN      30
# 8    7521    WARD   SALESMAN  7698.0  02/22/2001  1250   500.0      30
# 9    7902    FORD    ANALYST  7566.0  02/03/2001  3000     NaN      20
# 10   7369   SMITH      CLERK  7902.0  12/17/2000   800     NaN      20
# 11   7788   SCOTT    ANALYST  7566.0  04/19/2007  3000     NaN      20
# ...

# %%
emp.head()
# Out:
#    empno   ename        job     mgr    hiredate   sal    comm  deptno
# 0   7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1   7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2   7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 3   7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 4   7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30

# %%
emp.tail()
# Out:
#     empno   ename      job     mgr    hiredate   sal  comm  deptno
# 9    7902    FORD  ANALYST  7566.0  02/03/2001  3000   NaN      20
# 10   7369   SMITH    CLERK  7902.0  12/17/2000   800   NaN      20
# 11   7788   SCOTT  ANALYST  7566.0  04/19/2007  3000   NaN      20
# 12   7876   ADAMS    CLERK  7788.0  05/23/2007  1100   NaN      20
# 13   7934  MILLER    CLERK  7782.0  01/23/2002  1300   NaN      10

# %%
emp.sort_values("job")
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno
# 9    7902    FORD    ANALYST  7566.0  02/03/2001  3000     NaN      20
# 11   7788   SCOTT    ANALYST  7566.0  04/19/2007  3000     NaN      20
# 7    7900   JAMES      CLERK  7698.0  12/03/2001   950     NaN      30
# 10   7369   SMITH      CLERK  7902.0  12/17/2000   800     NaN      20
# 12   7876   ADAMS      CLERK  7788.0  05/23/2007  1100     NaN      20
# 13   7934  MILLER      CLERK  7782.0  01/23/2002  1300     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2    7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 3    7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 0    7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 4    7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0  02/20/2001  1600   300.0      30
# ...

# %%
emp.sample(5)
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno
# 4    7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
# 0    7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 11   7788   SCOTT    ANALYST  7566.0  04/19/2007  3000     NaN      20
# 9    7902    FORD    ANALYST  7566.0  02/03/2001  3000     NaN      20
# 8    7521    WARD   SALESMAN  7698.0  02/22/2001  1250   500.0      30

# %%
emp[['empno','ename','sal']].head()
# Out:
#    empno   ename   sal
# 0   7839    KING  5000
# 1   7698   BLAKE  2850
# 2   7782   CLARK  2450
# 3   7566   JONES  2975
# 4   7654  MARTIN  1250

# %%
col = ['empno','ename','sal','deptno']
emp[col]    #select 'empno','ename','sal','deptno' frpm emp
# Out:
#     empno   ename   sal  deptno
# 0    7839    KING  5000      10
# 1    7698   BLAKE  2850      30
# 2    7782   CLARK  2450      10
# 3    7566   JONES  2975      20
# 4    7654  MARTIN  1250      30
# 5    7499   ALLEN  1600      30
# 6    7844  TURNER  1500      30
# 7    7900   JAMES   950      30
# 8    7521    WARD  1250      30
# 9    7902    FORD  3000      20
# 10   7369   SMITH   800      20
# 11   7788   SCOTT  3000      20
# 12   7876   ADAMS  1100      20
# 13   7934  MILLER  1300      10

# %%
emp.groupby("sal").size()
# Out:
# sal
# 800     1
# 950     1
# 1100    1
# 1250    2
# 1300    1
# 1500    1
# 1600    1
# 2450    1
# 2850    1
# 2975    1
# 3000    2
# 5000    1
# dtype: int64

# %%
emp.loc[emp["sal"] <= 800]
# Out:
#     empno  ename    job     mgr    hiredate  sal  comm  deptno
# 10   7369  SMITH  CLERK  7902.0  12/17/2000  800   NaN      20

# %%
emp[['empno','ename','sal']].sort_values(by='ename', ascending=True)
# Out:
#     empno   ename   sal
# 12   7876   ADAMS  1100
# 5    7499   ALLEN  1600
# 1    7698   BLAKE  2850
# 2    7782   CLARK  2450
# 9    7902    FORD  3000
# 7    7900   JAMES   950
# 3    7566   JONES  2975
# 0    7839    KING  5000
# 4    7654  MARTIN  1250
# 13   7934  MILLER  1300
# 11   7788   SCOTT  3000
# 10   7369   SMITH   800
# 6    7844  TURNER  1500
# 8    7521    WARD  1250

# %%
emp[['empno','ename','sal']].rename(columns = {'sal':'salary','ename':'Employee'})
# Out:
#     empno Employee  salary
# 0    7839     KING    5000
# 1    7698    BLAKE    2850
# 2    7782    CLARK    2450
# 3    7566    JONES    2975
# 4    7654   MARTIN    1250
# 5    7499    ALLEN    1600
# 6    7844   TURNER    1500
# 7    7900    JAMES     950
# 8    7521     WARD    1250
# 9    7902     FORD    3000
# 10   7369    SMITH     800
# 11   7788    SCOTT    3000
# 12   7876    ADAMS    1100
# 13   7934   MILLER    1300

# %%
emp2 = emp[['empno','ename','sal']]
emp2['Annual Salary'] = emp2.sal * 12
emp2
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6648\1159898203.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emp2['Annual Salary'] = emp2.sal * 12
#     empno   ename   sal  Annual Salary
# 0    7839    KING  5000          60000
# 1    7698   BLAKE  2850          34200
# 2    7782   CLARK  2450          29400
# 3    7566   JONES  2975          35700
# 4    7654  MARTIN  1250          15000
# 5    7499   ALLEN  1600          19200
# 6    7844  TURNER  1500          18000
# 7    7900   JAMES   950          11400
# 8    7521    WARD  1250          15000
# 9    7902    FORD  3000          36000
# 10   7369   SMITH   800           9600
# 11   7788   SCOTT  3000          36000
# 12   7876   ADAMS  1100          13200
# ...

# %%
emp[['empno','ename','sal','deptno']][(emp.deptno == 10) & (emp.sal > 1000)]

#select 'empno','ename','sal','deptno' from emp
# where (emp.deptno ==10 ) & (emp.sal > 1000)
# Out:
#     empno   ename   sal  deptno
# 0    7839    KING  5000      10
# 2    7782   CLARK  2450      10
# 13   7934  MILLER  1300      10

# %%
emp[['empno','ename','sal','deptno']][emp.ename.str.startswith('A')] #A%

# Select empno,ename,sal,deptno from emp
#where emp.ename LIKE 'A%'
# Out:
#     empno  ename   sal  deptno
# 5    7499  ALLEN  1600      30
# 12   7876  ADAMS  1100      20

# %%
emp[['empno','ename','sal','deptno']][emp.ename.str.endswith('N')] #%N
# Out:
#    empno   ename   sal  deptno
# 4   7654  MARTIN  1250      30
# 5   7499   ALLEN  1600      30

# %%
emp[['empno','ename','sal','deptno']][emp.ename.str.contains('A')] #%A%
# Out:
#     empno   ename   sal  deptno
# 1    7698   BLAKE  2850      30
# 2    7782   CLARK  2450      10
# 4    7654  MARTIN  1250      30
# 5    7499   ALLEN  1600      30
# 7    7900   JAMES   950      30
# 8    7521    WARD  1250      30
# 12   7876   ADAMS  1100      20

# %%
emp[['empno','ename','sal','deptno']][emp.ename.str.startswith('A') & emp.ename.str.endswith('N')]
# Out:
#    empno  ename   sal  deptno
# 5   7499  ALLEN  1600      30

# %%
emp[['empno','ename','sal','deptno']][emp.ename.str.startswith('A') | emp.ename.str.endswith('N')]
# Out:
#     empno   ename   sal  deptno
# 4    7654  MARTIN  1250      30
# 5    7499   ALLEN  1600      30
# 12   7876   ADAMS  1100      20

# %%
emp.agg(TotalEmp = ('empno', 'count'), AvgSal = ('sal', 'mean'), SumSal = ('sal', 'sum'))
# SELECT COUNT(empno) AS TotalEmp, AVG(sal) AS AvgSal, SUM(sal) FROM emp
# Out:
#           empno           sal
# TotalEmp   14.0           NaN
# AvgSal      NaN   2073.214286
# SumSal      NaN  29025.000000

# %% [markdown]
# ## transpos

# %%
emp.agg(TotalEmp = ('empno', 'count'), AvgSal = ('sal', 'mean'), SumSal = ('sal', 'sum')).T
# Out:
#        TotalEmp       AvgSal   SumSal
# empno      14.0          NaN      NaN
# sal         NaN  2073.214286  29025.0

# %%
emp.agg(TotalEmp = ('empno', 'count'), AvgSal = ('sal', 'mean'), SumSal = ('sal', 'sum')).reset_index()
# Out:
#       index  empno           sal
# 0  TotalEmp   14.0           NaN
# 1    AvgSal    NaN   2073.214286
# 2    SumSal    NaN  29025.000000

# %%
emp02 = emp.groupby('deptno').agg(TotalEmp = ('empno', 'count'), \
                                  AvgSal = ('sal', 'mean'), SumSal = ('sal', 'sum')).reset_index()
emp02

#select deptno, COUNT(emp) as TotalEmp, Avg(sal) as AvgSal,SUM(sal) as SumSal
# From emp
# GROUP BY deptno
# Out:
#    deptno  TotalEmp       AvgSal  SumSal
# 0      10         3  2916.666667    8750
# 1      20         5  2175.000000   10875
# 2      30         6  1566.666667    9400

# %%
emp02[emp02.TotalEmp > 3]
#select deptno, COUNT(emp) as TotalEmp, Avg(sal) as AvgSal,SUM(sal) as SumSal
# From emp
# GROUP BY deptno
# HAVING TotalEMo > 3
# Out:
#    deptno  TotalEmp       AvgSal  SumSal
# 1      20         5  2175.000000   10875
# 2      30         6  1566.666667    9400

# %%
emp02 = emp.groupby(['deptno', 'job']).agg(TotalEmp = ('empno', 'count'), \
                                  AvgSal = ('sal', 'mean'), SumSal = ('sal', 'sum')).reset_index()
emp02

#select deptno,job, COUNT(emp) as TotalEmp, Avg(sal) as AvgSal,SUM(sal) as SumSal
# From emp
# GROUP BY deptno, job
# Out:
#    deptno        job  TotalEmp  AvgSal  SumSal
# 0      10      CLERK         1  1300.0    1300
# 1      10    MANAGER         1  2450.0    2450
# 2      10  PRESIDENT         1  5000.0    5000
# 3      20    ANALYST         2  3000.0    6000
# 4      20      CLERK         2   950.0    1900
# 5      20    MANAGER         1  2975.0    2975
# 6      30      CLERK         1   950.0     950
# 7      30    MANAGER         1  2850.0    2850
# 8      30   SALESMAN         4  1400.0    5600

# %%
emp02 = emp.groupby(['deptno', 'job']).agg(TotalEmp = ('empno', 'count'), \
                                  AvgSal = ('sal', 'mean'), SumSal = ('sal', 'sum'))
emp02
# Out:
#                   TotalEmp  AvgSal  SumSal
# deptno job
# 10     CLERK             1  1300.0    1300
#        MANAGER           1  2450.0    2450
#        PRESIDENT         1  5000.0    5000
# 20     ANALYST           2  3000.0    6000
#        CLERK             2   950.0    1900
#        MANAGER           1  2975.0    2975
# 30     CLERK             1   950.0     950
#        MANAGER           1  2850.0    2850
#        SALESMAN          4  1400.0    5600

# %%
e = emp
d = pd.read_csv("F:/DataSets/dept.csv")
print(e.columns)
print(d.columns)
# Out:
# Index(['empno', 'ename', 'job', 'mgr', 'hiredate', 'sal', 'comm', 'deptno'], dtype='object')
# Index(['deptno', 'dname', 'loc'], dtype='object')

# %%
# join all same column(s) name
pd.merge(e, d)
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno  \
# 0    7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1    7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 2    7934  MILLER      CLERK  7782.0  01/23/2002  1300     NaN      10
# 3    7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 4    7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0  02/20/2001  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0  09/08/2001  1500     0.0      30
# 7    7900   JAMES      CLERK  7698.0  12/03/2001   950     NaN      30
# 8    7521    WARD   SALESMAN  7698.0  02/22/2001  1250   500.0      30
# 9    7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 10   7902    FORD    ANALYST  7566.0  02/03/2001  3000     NaN      20
# 11   7369   SMITH      CLERK  7902.0  12/17/2000   800     NaN      20
# ...

# %%
pd.merge(e, d, on='deptno', how='inner')
# join specific same column(s) name
# joinin type
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno  \
# 0    7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1    7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 2    7934  MILLER      CLERK  7782.0  01/23/2002  1300     NaN      10
# 3    7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 4    7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0  02/20/2001  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0  09/08/2001  1500     0.0      30
# 7    7900   JAMES      CLERK  7698.0  12/03/2001   950     NaN      30
# 8    7521    WARD   SALESMAN  7698.0  02/22/2001  1250   500.0      30
# 9    7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 10   7902    FORD    ANALYST  7566.0  02/03/2001  3000     NaN      20
# 11   7369   SMITH      CLERK  7902.0  12/17/2000   800     NaN      20
# ...

# %%
pd.merge(e, d, left_on='deptno', right_on='deptno', how='inner')
# join specific differ column(s) name
# joinin type
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno  \
# 0    7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1    7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 2    7934  MILLER      CLERK  7782.0  01/23/2002  1300     NaN      10
# 3    7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 4    7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0  02/20/2001  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0  09/08/2001  1500     0.0      30
# 7    7900   JAMES      CLERK  7698.0  12/03/2001   950     NaN      30
# 8    7521    WARD   SALESMAN  7698.0  02/22/2001  1250   500.0      30
# 9    7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 10   7902    FORD    ANALYST  7566.0  02/03/2001  3000     NaN      20
# 11   7369   SMITH      CLERK  7902.0  12/17/2000   800     NaN      20
# ...

# %%
pd.merge(e, d, on='deptno', how='right')
# Out:
#      empno   ename        job     mgr    hiredate     sal    comm  deptno  \
# 0   7839.0    KING  PRESIDENT     NaN  11/17/2001  5000.0     NaN      10
# 1   7782.0   CLARK    MANAGER  7839.0  06/09/2001  2450.0     NaN      10
# 2   7934.0  MILLER      CLERK  7782.0  01/23/2002  1300.0     NaN      10
# 3   7566.0   JONES    MANAGER  7839.0  04/02/2001  2975.0     NaN      20
# 4   7902.0    FORD    ANALYST  7566.0  02/03/2001  3000.0     NaN      20
# 5   7369.0   SMITH      CLERK  7902.0  12/17/2000   800.0     NaN      20
# 6   7788.0   SCOTT    ANALYST  7566.0  04/19/2007  3000.0     NaN      20
# 7   7876.0   ADAMS      CLERK  7788.0  05/23/2007  1100.0     NaN      20
# 8   7698.0   BLAKE    MANAGER  7839.0  05/01/2001  2850.0     NaN      30
# 9   7654.0  MARTIN   SALESMAN  7698.0  09/28/2001  1250.0  1400.0      30
# 10  7499.0   ALLEN   SALESMAN  7698.0  02/20/2001  1600.0   300.0      30
# 11  7844.0  TURNER   SALESMAN  7698.0  09/08/2001  1500.0     0.0      30
# ...

# %%
pd.merge(e, d, on='deptno', how='outer',indicator=True)
# Out:
#      empno   ename        job     mgr    hiredate     sal    comm  deptno  \
# 0   7839.0    KING  PRESIDENT     NaN  11/17/2001  5000.0     NaN      10
# 1   7782.0   CLARK    MANAGER  7839.0  06/09/2001  2450.0     NaN      10
# 2   7934.0  MILLER      CLERK  7782.0  01/23/2002  1300.0     NaN      10
# 3   7698.0   BLAKE    MANAGER  7839.0  05/01/2001  2850.0     NaN      30
# 4   7654.0  MARTIN   SALESMAN  7698.0  09/28/2001  1250.0  1400.0      30
# 5   7499.0   ALLEN   SALESMAN  7698.0  02/20/2001  1600.0   300.0      30
# 6   7844.0  TURNER   SALESMAN  7698.0  09/08/2001  1500.0     0.0      30
# 7   7900.0   JAMES      CLERK  7698.0  12/03/2001   950.0     NaN      30
# 8   7521.0    WARD   SALESMAN  7698.0  02/22/2001  1250.0   500.0      30
# 9   7566.0   JONES    MANAGER  7839.0  04/02/2001  2975.0     NaN      20
# 10  7902.0    FORD    ANALYST  7566.0  02/03/2001  3000.0     NaN      20
# 11  7369.0   SMITH      CLERK  7902.0  12/17/2000   800.0     NaN      20
# ...

# %%
pd.merge(e, d, on='deptno', how='inner',validate='many_to_one')
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno  \
# 0    7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1    7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 2    7934  MILLER      CLERK  7782.0  01/23/2002  1300     NaN      10
# 3    7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 4    7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0  02/20/2001  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0  09/08/2001  1500     0.0      30
# 7    7900   JAMES      CLERK  7698.0  12/03/2001   950     NaN      30
# 8    7521    WARD   SALESMAN  7698.0  02/22/2001  1250   500.0      30
# 9    7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 10   7902    FORD    ANALYST  7566.0  02/03/2001  3000     NaN      20
# 11   7369   SMITH      CLERK  7902.0  12/17/2000   800     NaN      20
# ...

# %%
e = emp
m = emp

# %%
pd.merge(e, m, left_on='mgr', right_on='empno', how='inner')[['empno_x','ename_x','mgr_x','ename_y']]



# Select e.empno, e.ename, e.mgr, mnename
# from emp e Inner JOIN emp m ON e.mgr=e.empno
# Out:
#     empno_x ename_x   mgr_x ename_y
# 0      7698   BLAKE  7839.0    KING
# 1      7782   CLARK  7839.0    KING
# 2      7566   JONES  7839.0    KING
# 3      7654  MARTIN  7698.0   BLAKE
# 4      7499   ALLEN  7698.0   BLAKE
# 5      7844  TURNER  7698.0   BLAKE
# 6      7900   JAMES  7698.0   BLAKE
# 7      7521    WARD  7698.0   BLAKE
# 8      7902    FORD  7566.0   JONES
# 9      7788   SCOTT  7566.0   JONES
# 10     7369   SMITH  7902.0    FORD
# 11     7876   ADAMS  7788.0   SCOTT
# 12     7934  MILLER  7782.0   CLARK

# %%
pd.merge(e, m, left_on='mgr', right_on='empno', how='left')[['empno_x','ename_x','mgr_x','ename_y']]
# Out:
#     empno_x ename_x   mgr_x ename_y
# 0      7839    KING     NaN     NaN
# 1      7698   BLAKE  7839.0    KING
# 2      7782   CLARK  7839.0    KING
# 3      7566   JONES  7839.0    KING
# 4      7654  MARTIN  7698.0   BLAKE
# 5      7499   ALLEN  7698.0   BLAKE
# 6      7844  TURNER  7698.0   BLAKE
# 7      7900   JAMES  7698.0   BLAKE
# 8      7521    WARD  7698.0   BLAKE
# 9      7902    FORD  7566.0   JONES
# 10     7369   SMITH  7902.0    FORD
# 11     7788   SCOTT  7566.0   JONES
# 12     7876   ADAMS  7788.0   SCOTT
# 13     7934  MILLER  7782.0   CLARK

# %%
pd.merge(e, m, left_on='mgr', right_on='empno', how='left')[['empno_x','ename_x','job_x','mgr_x','ename_y']]
# Out:
#     empno_x ename_x      job_x   mgr_x ename_y
# 0      7839    KING  PRESIDENT     NaN     NaN
# 1      7698   BLAKE    MANAGER  7839.0    KING
# 2      7782   CLARK    MANAGER  7839.0    KING
# 3      7566   JONES    MANAGER  7839.0    KING
# 4      7654  MARTIN   SALESMAN  7698.0   BLAKE
# 5      7499   ALLEN   SALESMAN  7698.0   BLAKE
# 6      7844  TURNER   SALESMAN  7698.0   BLAKE
# 7      7900   JAMES      CLERK  7698.0   BLAKE
# 8      7521    WARD   SALESMAN  7698.0   BLAKE
# 9      7902    FORD    ANALYST  7566.0   JONES
# 10     7369   SMITH      CLERK  7902.0    FORD
# 11     7788   SCOTT    ANALYST  7566.0   JONES
# 12     7876   ADAMS      CLERK  7788.0   SCOTT
# 13     7934  MILLER      CLERK  7782.0   CLARK

# %%
pd.merge(e, m, left_on='mgr', right_on='empno', how='right')[['empno_x','ename_x','job_x','mgr_x','ename_y']]
# Out:
#     empno_x ename_x     job_x   mgr_x ename_y
# 0    7698.0   BLAKE   MANAGER  7839.0    KING
# 1    7782.0   CLARK   MANAGER  7839.0    KING
# 2    7566.0   JONES   MANAGER  7839.0    KING
# 3    7654.0  MARTIN  SALESMAN  7698.0   BLAKE
# 4    7499.0   ALLEN  SALESMAN  7698.0   BLAKE
# 5    7844.0  TURNER  SALESMAN  7698.0   BLAKE
# 6    7900.0   JAMES     CLERK  7698.0   BLAKE
# 7    7521.0    WARD  SALESMAN  7698.0   BLAKE
# 8    7934.0  MILLER     CLERK  7782.0   CLARK
# 9    7902.0    FORD   ANALYST  7566.0   JONES
# 10   7788.0   SCOTT   ANALYST  7566.0   JONES
# 11      NaN     NaN       NaN     NaN  MARTIN
# 12      NaN     NaN       NaN     NaN   ALLEN
# 13      NaN     NaN       NaN     NaN  TURNER
# 14      NaN     NaN       NaN     NaN   JAMES
# 15      NaN     NaN       NaN     NaN    WARD
# 16   7369.0   SMITH     CLERK  7902.0    FORD
# 17      NaN     NaN       NaN     NaN   SMITH
# 18   7876.0   ADAMS     CLERK  7788.0   SCOTT
# ...

# %%
pd.merge(e, m, left_on='mgr', right_on='empno', how='outer')[['empno_x','ename_x','job_x','mgr_x','ename_y']]
# Out:
#     empno_x ename_x      job_x   mgr_x ename_y
# 0    7839.0    KING  PRESIDENT     NaN     NaN
# 1    7698.0   BLAKE    MANAGER  7839.0    KING
# 2    7782.0   CLARK    MANAGER  7839.0    KING
# 3    7566.0   JONES    MANAGER  7839.0    KING
# 4    7654.0  MARTIN   SALESMAN  7698.0   BLAKE
# 5    7499.0   ALLEN   SALESMAN  7698.0   BLAKE
# 6    7844.0  TURNER   SALESMAN  7698.0   BLAKE
# 7    7900.0   JAMES      CLERK  7698.0   BLAKE
# 8    7521.0    WARD   SALESMAN  7698.0   BLAKE
# 9    7902.0    FORD    ANALYST  7566.0   JONES
# 10   7788.0   SCOTT    ANALYST  7566.0   JONES
# 11   7369.0   SMITH      CLERK  7902.0    FORD
# 12   7876.0   ADAMS      CLERK  7788.0   SCOTT
# 13   7934.0  MILLER      CLERK  7782.0   CLARK
# 14      NaN     NaN        NaN     NaN  MARTIN
# 15      NaN     NaN        NaN     NaN   ALLEN
# 16      NaN     NaN        NaN     NaN  TURNER
# 17      NaN     NaN        NaN     NaN   JAMES
# 18      NaN     NaN        NaN     NaN    WARD
# ...
